# %%
import tensorflow as tf
import numpy as np

from sklearn.model_selection import train_test_split

import matplotlib.ticker as ticker
import matplotlib.pyplot as plt

import time
import re
import os
import io

# %%
path_to_dir = os.getenv('HOME') +'/aiffel/s2s_translation'
path_to_file_ko = path_to_dir +'/korean-english-park.train.ko'
path_to_file_en = path_to_dir +'/korean-english-park.train.en'

# %%
with open(path_to_file_ko, "r") as f:
    raw_ko = f.read().splitlines()
    
print("Data Size: ", len(raw_ko))
print("Example: ")

for sen in raw_ko[0:100][::20]:
    print(">>", sen)
# Out:
# Data Size:  94123
# Example:
# >> 개인용 컴퓨터 사용의 상당 부분은 "이것보다 뛰어날 수 있느냐?"
# >> 북한의 핵무기 계획을 포기하도록 하려는 압력이 거세지고 있는 가운데, 일본과 북한의 외교관들이 외교 관계를 정상화하려는 회담을 재개했다.
# >> "경호 로보트가 침입자나 화재를 탐지하기 위해서 개인적으로, 그리고 전문적으로 사용되고 있습니다."
# >> 수자원부 당국은 논란이 되고 있고, 막대한 비용이 드는 이 사업에 대해 내년에 건설을 시작할 계획이다.
# >> 또한 근력 운동은 활발하게 걷는 것이나 최소한 20분 동안 뛰는 것과 같은 유산소 활동에서 얻는 운동 효과를 심장과 폐에 주지 않기 때문에, 연구학자들은 근력 운동이 심장에 큰 영향을 미치는지 여부에 대해 논쟁을 해왔다.

# %%
with open(path_to_file_en, "r") as f:
    raw_en = f.read().splitlines()
    
print("Data Size: ", len(raw_en))
print("Example: ")

for sen in raw_en[0:100][::20]:
    print(">>", sen)
# Out:
# Data Size:  94123
# Example:
# >> Much of personal computing is about "can you top this?"
# >> Amid mounting pressure on North Korea to abandon its nuclear weapons program Japanese and North Korean diplomats have resumed talks on normalizing diplomatic relations.
# >> “Guard robots are used privately and professionally to detect intruders or fire,” Karlsson said.
# >> Authorities from the Water Resources Ministry plan to begin construction next year on the controversial and hugely expensive project.
# >> Researchers also have debated whether weight-training has a big impact on the heart, since it does not give the heart and lungs the kind of workout they get from aerobic activities such as brisk walking or running for at least 20 minutes.

# %%
raw = zip(raw_ko, raw_en)

# %%
cleaned_corpus = set(raw)

# %%
len(cleaned_corpus)
# Out:
# 78968

# %%
from konlpy.tag import Mecab
mecab = Mecab()

def preprocess_sentence(sentence, s_token=False, e_token=False):
    sentence = sentence.lower().strip()

    sentence = re.sub(r"([?.!,])", r" \1 ", sentence)
    sentence = re.sub(r'[" "]+', " ", sentence)
    #한글 포함
    sentence = re.sub(r"[^a-zA-Z|0-9|ㄱ-하-ㅣ가-힣?.!,]+", " ", sentence)

    sentence = sentence.strip()

    if s_token:
        sentence = '<start> ' + sentence

    if e_token:
        sentence += ' <end>'
        
    if s_token == False:
        sentence = mecab.morphs(sentence)
    else:
        sentence = sentence.split()
        
    return sentence

# %%
corpus_list = list(cleaned_corpus)

# %%
corpus_list[100]
# Out:
# ('다이애나는 지난 1997년 7월, 18개월간 사귀던 칸과 헤어지면서 파예드를 만나기 시작했다.',
#  "Diana's 18-month relationship with Khan ended around the same time she started seeing Fayed in July 1997.")

# %%
kor_corpus = []
eng_corpus = []


num_examples = len(corpus_list)

for pair in corpus_list[:3500]:
    ret_ko = preprocess_sentence(pair[0])
    ret_en = preprocess_sentence(pair[1], s_token=True, e_token=True)
    if len(ret_ko) <= 40:
#    if len(ret_ko) <= 20:
        kor_corpus.append(ret_ko)
        eng_corpus.append(ret_en)

print(len(kor_corpus))
print(len(eng_corpus))
print("Korean:", kor_corpus[100])   
print("English:", eng_corpus[100])
# Out:
# 2844
# 2844
# Korean: ['수납', '함', '과', '탁자', '위', '를', '정리', '하', '고', '의미', '있', '고', '예쁜', '소품', '들', '로', '교체', '한다', '.']
# English: ['<start>', 'clear', 'of', 'the', 'surfaces', 'of', 'chests', 'and', 'tables', ',', 'and', 'only', 'replace', 'what', 'is', 'meaningful', 'or', 'pretty', '.', '<end>']

# %%
def tokenize(corpus):
    tokenizer = tf.keras.preprocessing.text.Tokenizer(filters='')
    tokenizer.fit_on_texts(corpus)

    tensor = tokenizer.texts_to_sequences(corpus)

    tensor = tf.keras.preprocessing.sequence.pad_sequences(tensor, padding='post')

    return tensor, tokenizer

# %%
# 토큰화하기
# 훈련 데이터와 검증 데이터로 분리하기

enc_tensor, enc_tokenizer = tokenize(kor_corpus)
dec_tensor, dec_tokenizer = tokenize(eng_corpus)

enc_train, enc_val, dec_train, dec_val = \
train_test_split(enc_tensor, dec_tensor, test_size=0.2)

print("Korean Vocab Size:", len(enc_tokenizer.index_word))
print("English Vocab Size:", len(dec_tokenizer.index_word))
# Out:
# Korean Vocab Size: 10326
# English Vocab Size: 10228

# %%
class BahdanauAttention(tf.keras.layers.Layer):
    def __init__(self, units):
        super(BahdanauAttention, self).__init__()
        self.w_dec = tf.keras.layers.Dense(units)
        self.w_enc = tf.keras.layers.Dense(units)
        self.w_com = tf.keras.layers.Dense(1)
    
    def call(self, h_enc, h_dec):
        # h_enc shape: [batch x length x units]
        # h_dec shape: [batch x units]

        h_enc = self.w_enc(h_enc)
        h_dec = tf.expand_dims(h_dec, 1)
        h_dec = self.w_dec(h_dec)

        score = self.w_com(tf.nn.tanh(h_dec + h_enc))
        
        attn = tf.nn.softmax(score, axis=1)

        context_vec = attn * h_enc
        context_vec = tf.reduce_sum(context_vec, axis=1)

        return context_vec, attn

# %%
class Encoder(tf.keras.Model):
    def __init__(self, vocab_size, embedding_dim, enc_units):
        super(Encoder, self).__init__()

        self.enc_units = enc_units
        self.embedding = tf.keras.layers.Embedding(vocab_size, embedding_dim)
        self.gru = tf.keras.layers.GRU(enc_units,
                                       return_sequences=True)

    def call(self, x):
        out = self.embedding(x)
        out = self.gru(out)

        return out

# %%
class Decoder(tf.keras.Model):
    def __init__(self, vocab_size, embedding_dim, dec_units):
        super(Decoder, self).__init__()
        self.dec_units = dec_units
        self.embedding = tf.keras.layers.Embedding(vocab_size, embedding_dim)
        self.gru = tf.keras.layers.GRU(dec_units,
                                       return_sequences=True,
                                       return_state=True)
        self.fc = tf.keras.layers.Dense(vocab_size)

        self.attention = BahdanauAttention(self.dec_units)

    def call(self, x, h_dec, enc_out):
        context_vec, attn = self.attention(enc_out, h_dec)

        out = self.embedding(x)
        out = tf.concat([tf.expand_dims(context_vec, 1), out], axis=-1)

        out, h_dec = self.gru(out)
        out = tf.reshape(out, (-1, out.shape[2]))
        out = self.fc(out)

        return out, h_dec, attn

# %%
# 코드를 실행하세요.

#BATCH_SIZE     = 64
BATCH_SIZE     = 1
SRC_VOCAB_SIZE =  len(enc_tokenizer.index_word) + 1
TGT_VOCAB_SIZE = len(dec_tokenizer.index_word) + 1
#SRC_VOCAB_SIZE =  10000 #len(enc_tokenizer.index_word) + 1
#TGT_VOCAB_SIZE = 10000 #len(dec_tokenizer.index_word) + 1

units         = 1024
#units         = 512
embedding_dim = 512
#embedding_dim = 128

encoder = Encoder(SRC_VOCAB_SIZE, embedding_dim, units)
decoder = Decoder(TGT_VOCAB_SIZE, embedding_dim, units)

# sample input
sequence_len = 30

sample_enc = tf.random.uniform((BATCH_SIZE, sequence_len))
sample_output = encoder(sample_enc)

print ('Encoder Output:', sample_output.shape)

sample_state = tf.random.uniform((BATCH_SIZE, units))

sample_logits, h_dec, attn = decoder(tf.random.uniform((BATCH_SIZE, 1)),
                                     sample_state, sample_output)

print ('Decoder Output:', sample_logits.shape)
print ('Decoder Hidden State:', h_dec.shape)
print ('Attention:', attn.shape)
# Out:
# Encoder Output: (1, 30, 1024)
# Decoder Output: (1, 10229)
# Decoder Hidden State: (1, 1024)
# Attention: (1, 30, 1)

# %%
optimizer = tf.keras.optimizers.Adam()
loss_object = tf.keras.losses.SparseCategoricalCrossentropy(
    from_logits=True, reduction='none')

def loss_function(real, pred):
    mask = tf.math.logical_not(tf.math.equal(real, 0))
    loss = loss_object(real, pred)
    
    mask = tf.cast(mask, dtype=loss.dtype)
    loss *= mask
    
    return tf.reduce_mean(loss)

# %%
@tf.function
def train_step(src, tgt, encoder, decoder, optimizer, dec_tok):
    bsz = src.shape[0]
    loss = 0

    with tf.GradientTape() as tape:
        enc_out = encoder(src)
        h_dec = enc_out[:, -1]
        
        dec_src = tf.expand_dims([dec_tok.word_index['<start>']] * bsz, 1)

        for t in range(1, tgt.shape[1]):
            pred, h_dec, _ = decoder(dec_src, h_dec, enc_out)

            loss += loss_function(tgt[:, t], pred)
            dec_src = tf.expand_dims(tgt[:, t], 1)
        
    batch_loss = (loss / int(tgt.shape[1]))

    variables = encoder.trainable_variables + decoder.trainable_variables
    gradients = tape.gradient(loss, variables)
    optimizer.apply_gradients(zip(gradients, variables))
    
    return batch_loss

# %%
import os
os.environ["TF_FORCE_GPU_ALLOW_GROWTH"]="true"

# %%
from tqdm import tqdm    # tqdm
import random

EPOCHS = 10

for epoch in range(EPOCHS):
    total_loss = 0
    
    idx_list = list(range(0, enc_train.shape[0], BATCH_SIZE))
    random.shuffle(idx_list)
    t = tqdm(idx_list)    # tqdm

    for (batch, idx) in enumerate(t):
        batch_loss = train_step(enc_train[idx:idx+BATCH_SIZE],
                                dec_train[idx:idx+BATCH_SIZE],
                                encoder,
                                decoder,
                                optimizer,
                                dec_tokenizer)
    
        total_loss += batch_loss
        
        t.set_description_str('Epoch %2d' % (epoch + 1))    # tqdm
        t.set_postfix_str('Loss %.4f' % (total_loss.numpy() / (batch + 1)))    # tqdm
# Out:
# Epoch  1: 100%|██████████| 2275/2275 [12:35<00:00,  3.01it/s, Loss 2.8140]
# Epoch  2: 100%|██████████| 2275/2275 [11:17<00:00,  3.36it/s, Loss 2.7647]
# Epoch  3: 100%|██████████| 2275/2275 [11:16<00:00,  3.36it/s, Loss 2.6265]
# Epoch  4: 100%|██████████| 2275/2275 [11:15<00:00,  3.37it/s, Loss 2.5287]
# Epoch  5: 100%|██████████| 2275/2275 [11:16<00:00,  3.36it/s, Loss 2.4343]
# Epoch  6: 100%|██████████| 2275/2275 [11:15<00:00,  3.37it/s, Loss 2.3882]
# Epoch  7: 100%|██████████| 2275/2275 [11:14<00:00,  3.37it/s, Loss 2.3533]
# Epoch  8: 100%|██████████| 2275/2275 [11:13<00:00,  3.38it/s, Loss 2.3199]
# Epoch  9: 100%|██████████| 2275/2275 [11:13<00:00,  3.38it/s, Loss 2.3532]
# Epoch 10: 100%|██████████| 2275/2275 [11:13<00:00,  3.38it/s, Loss 2.4640]

# %%
dec_tokenizer.word_index
# Out:
# {'the': 1,
#  '.': 2,
#  ',': 3,
#  '<start>': 4,
#  '<end>': 5,
#  'to': 6,
#  'of': 7,
#  'a': 8,
#  'in': 9,
#  'and': 10,
#  's': 11,
#  'said': 12,
#  'for': 13,
#  'on': 14,
#  'that': 15,
#  'is': 16,
#  'was': 17,
#  'with': 18,
#  'at': 19,
#  'he': 20,
#  'it': 21,
#  'as': 22,
#  'from': 23,
#  'by': 24,
#  'has': 25,
#  'have': 26,
#  'be': 27,
#  'his': 28,
#  'are': 29,
#  'an': 30,
#  'were': 31,
#  'will': 32,
#  'been': 33,
#  'had': 34,
#  'but': 35,
#  'not': 36,
#  'after': 37,
#  'its': 38,
#  'they': 39,
#  'their': 40,
#  'u': 41,
#  'who': 42,
#  'also': 43,
#  'this': 44,
#  'her': 45,
#  'new': 46,
#  'more': 47,
#  'about': 48,
#  'people': 49,
#  'up': 50,
#  'one': 51,
#  'president': 52,
#  'korea': 53,
#  'two': 54,
#  'i': 55,
#  'she': 56,
#  'last': 57,
#  'which': 58,
#  'north': 59,
#  'government': 60,
#  'there': 61,
#  'first': 62,
#  'or': 63,
#  'police': 64,
#  'than': 65,
#  'south': 66,
#  'we': 67,
#  'would': 68,
#  'out': 69,
#  'percent': 70,
#  'year': 71,
#  'when': 72,
#  'into': 73,
#  'cnn': 74,
#  'no': 75,
#  'years': 76,
#  'other': 77,
#  't': 78,
#  'over': 79,
#  'all': 80,
#  'united': 81,
#  'according': 82,
#  'monday': 83,
#  'iraq': 84,
#  'state': 85,
#  'says': 86,
#  'time': 87,
#  'you': 88,
#  'officials': 89,
#  'korean': 90,
#  'could': 91,
#  'country': 92,
#  'made': 93,
#  'if': 94,
#  'told': 95,
#  'world': 96,
#  'tuesday': 97,
#  'former': 98,
#  'minister': 99,
#  'since': 100,
#  'some': 101,
#  'where': 102,
#  'reported': 103,
#  '1': 104,
#  'wednesday': 105,
#  'news': 106,
#  'million': 107,
#  'before': 108,
#  'three': 109,
#  '000': 110,
#  'sunday': 111,
#  'party': 112,
#  'china': 113,
#  'city': 114,
#  'while': 115,
#  'house': 116,
#  'killed': 117,
#  'obama': 118,
#  'states': 119,
#  'most': 120,
#  'only': 121,
#  'national': 122,
#  'nuclear': 123,
#  'military': 124,
#  'between': 125,
#  'being': 126,
#  'can': 127,
#  'week': 128,
#  'any': 129,
#  'security': 130,
#  'them': 131,
#  'bush': 132,
#  'him': 133,
#  'through': 134,
#  'office': 135,
#  'talks': 136,
#  'under': 137,
#  'down': 138,
#  'end': 139,
#  'prime': 140,
#  'second': 141,
#  'japan': 142,
#  'thursday': 143,
#  'against': 144,
#  'war': 145,
#  'what': 146,
#  'because': 147,
#  'day': 148,
#  '2': 149,
#  'say': 150,
#  'just': 151,
#  'us': 152,
#  'reports': 153,
#  'home': 154,
#  'least': 155,
#  'foreign': 156,
#  'still': 157,
#  'troops': 158,
#  'group': 159,
#  'called': 160,
#  'days': 161,
#  'won': 162,
#  'official': 163,
#  'statement': 164,
#  'back': 165,
#  'many': 166,
#  'then': 167,
#  'agency': 168,
#  'york': 169,
#  '3': 170,
#  'five': 171,
#  'spokesman': 172,
#  'may': 173,
#  'our': 174,
#  'during': 175,
#  'iraqi': 176,
#  'those': 177,
#  'so': 178,
#  'take': 179,
#  'presidential': 180,
#  'around': 181,
#  'later': 182,
#  'court': 183,
#  'among': 184,
#  'expected': 185,
#  'campaign': 186,
#  'top': 187,
#  'international': 188,
#  'used': 189,
#  'such': 190,
#  'both': 191,
#  'white': 192,
#  'including': 193,
#  'meeting': 194,
#  'opposition': 195,
#  'leader': 196,
#  'saying': 197,
#  'next': 198,
#  'n': 199,
#  'found': 200,
#  'chief': 201,
#  'recent': 202,
#  'march': 203,
#  'early': 204,
#  'report': 205,
#  'american': 206,
#  'countries': 207,
#  'how': 208,
#  'now': 209,
#  'months': 210,
#  'ministry': 211,
#  'public': 212,
#  'ago': 213,
#  'make': 214,
#  '10': 215,
#  'forces': 216,
#  'members': 217,
#  '20': 218,
#  'kim': 219,
#  'women': 220,
#  'month': 221,
#  'get': 222,
#  'rights': 223,
#  'students': 224,
#  'my': 225,
#  'lee': 226,
#  'seoul': 227,
#  'm': 228,
#  'main': 229,
#  'four': 230,
#  'came': 231,
#  'very': 232,
#  'off': 233,
#  'department': 234,
#  'near': 235,
#  'even': 236,
#  'part': 237,
#  'died': 238,
#  'billion': 239,
#  'authorities': 240,
#  'force': 241,
#  'power': 242,
#  'attack': 243,
#  'children': 244,
#  'saturday': 245,
#  'until': 246,
#  'here': 247,
#  'today': 248,
#  'do': 249,
#  'bank': 250,
#  'put': 251,
#  'work': 252,
#  'fire': 253,
#  '30': 254,
#  'california': 255,
#  '15': 256,
#  'already': 257,
#  'times': 258,
#  'like': 259,
#  'lead': 260,
#  'number': 261,
#  'come': 262,
#  'clinton': 263,
#  'death': 264,
#  '4': 265,
#  'chinese': 266,
#  'major': 267,
#  'democratic': 268,
#  'election': 269,
#  'high': 270,
#  'man': 271,
#  'japanese': 272,
#  'left': 273,
#  'deal': 274,
#  'iran': 275,
#  'nearly': 276,
#  'latest': 277,
#  'life': 278,
#  'company': 279,
#  'earlier': 280,
#  'should': 281,
#  'well': 282,
#  'financial': 283,
#  'few': 284,
#  'food': 285,
#  'third': 286,
#  'taken': 287,
#  'baghdad': 288,
#  'however': 289,
#  'plans': 290,
#  'media': 291,
#  'car': 292,
#  'trade': 293,
#  'taliban': 294,
#  'nations': 295,
#  'miles': 296,
#  'yesterday': 297,
#  'set': 298,
#  'press': 299,
#  'think': 300,
#  'held': 301,
#  'show': 302,
#  'hospital': 303,
#  '?': 304,
#  'capital': 305,
#  'hit': 306,
#  'same': 307,
#  'men': 308,
#  'another': 309,
#  'site': 310,
#  'across': 311,
#  'much': 312,
#  'london': 313,
#  'leaders': 314,
#  'return': 315,
#  'your': 316,
#  'economic': 317,
#  'decision': 318,
#  'parties': 319,
#  'support': 320,
#  'dead': 321,
#  'likely': 322,
#  'building': 323,
#  'several': 324,
#  'attacks': 325,
#  'afghanistan': 326,
#  'announced': 327,
#  'case': 328,
#  'oil': 329,
#  'economy': 330,
#  'program': 331,
#  'use': 332,
#  'agreement': 333,
#  'final': 334,
#  'university': 335,
#  'british': 336,
#  'friday': 337,
#  'plan': 338,
#  'john': 339,
#  'conference': 340,
#  'political': 341,
#  'school': 342,
#  'don': 343,
#  'russia': 344,
#  'washington': 345,
#  'southern': 346,
#  'secretary': 347,
#  'militants': 348,
#  'rice': 349,
#  'own': 350,
#  'further': 351,
#  'long': 352,
#  'energy': 353,
#  'issue': 354,
#  'started': 355,
#  'video': 356,
#  'thousands': 357,
#  'getting': 358,
#  'close': 359,
#  'term': 360,
#  'violence': 361,
#  '11': 362,
#  'area': 363,
#  'pyongyang': 364,
#  '5': 365,
#  'help': 366,
#  'might': 367,
#  'behind': 368,
#  'vote': 369,
#  'french': 370,
#  'australian': 371,
#  'central': 372,
#  'due': 373,
#  'law': 374,
#  're': 375,
#  'internet': 376,
#  'late': 377,
#  'along': 378,
#  'key': 379,
#  '-': 380,
#  'hotel': 381,
#  '12': 382,
#  'crisis': 383,
#  'july': 384,
#  '100': 385,
#  'ap': 386,
#  'evidence': 387,
#  'job': 388,
#  'israeli': 389,
#  'without': 390,
#  'added': 391,
#  'want': 392,
#  'going': 393,
#  'pakistan': 394,
#  'six': 395,
#  'good': 396,
#  'past': 397,
#  've': 398,
#  'began': 399,
#  'hours': 400,
#  'took': 401,
#  'army': 402,
#  'general': 403,
#  'start': 404,
#  'future': 405,
#  'health': 406,
#  'january': 407,
#  'emergency': 408,
#  'free': 409,
#  'went': 410,
#  'koreans': 411,
#  'great': 412,
#  'got': 413,
#  'planned': 414,
#  'others': 415,
#  'given': 416,
#  'way': 417,
#  'released': 418,
#  'elections': 419,
#  'give': 420,
#  'team': 421,
#  'aid': 422,
#  'global': 423,
#  'water': 424,
#  'local': 425,
#  'following': 426,
#  'weeks': 427,
#  'barack': 428,
#  'market': 429,
#  'wounded': 430,
#  'seen': 431,
#  'away': 432,
#  'peace': 433,
#  'trying': 434,
#  'soldiers': 435,
#  'al': 436,
#  'province': 437,
#  'whether': 438,
#  'arrested': 439,
#  'town': 440,
#  'woman': 441,
#  'know': 442,
#  'web': 443,
#  'prices': 444,
#  'beijing': 445,
#  'must': 446,
#  'air': 447,
#  'defense': 448,
#  '40': 449,
#  'paris': 450,
#  'charges': 451,
#  'afghan': 452,
#  'money': 453,
#  'role': 454,
#  'having': 455,
#  'go': 456,
#  'change': 457,
#  'meet': 458,
#  'need': 459,
#  'estimated': 460,
#  'half': 461,
#  'bill': 462,
#  'suicide': 463,
#  'move': 464,
#  'human': 465,
#  'spokeswoman': 466,
#  'research': 467,
#  'outside': 468,
#  'accused': 469,
#  'making': 470,
#  'shot': 471,
#  'nation': 472,
#  'director': 473,
#  'd': 474,
#  'administration': 475,
#  'east': 476,
#  'ahead': 477,
#  'small': 478,
#  'turkey': 479,
#  'newspaper': 480,
#  'run': 481,
#  'mother': 482,
#  'april': 483,
#  'region': 484,
#  'article': 485,
#  'cut': 486,
#  'killing': 487,
#  'britain': 488,
#  'call': 489,
#  '2006': 490,
#  'big': 491,
#  'received': 492,
#  'union': 493,
#  'nine': 494,
#  'television': 495,
#  'polls': 496,
#  'candidate': 497,
#  'far': 498,
#  '200': 499,
#  'did': 500,
#  'brown': 501,
#  'too': 502,
#  'sales': 503,
#  'island': 504,
#  'using': 505,
#  'head': 506,
#  'victims': 507,
#  'mission': 508,
#  'play': 509,
#  'see': 510,
#  'bring': 511,
#  'gas': 512,
#  'right': 513,
#  'couple': 514,
#  'fell': 515,
#  'night': 516,
#  '6': 517,
#  'center': 518,
#  'september': 519,
#  'hundreds': 520,
#  'star': 521,
#  'england': 522,
#  'crash': 523,
#  'bomb': 524,
#  'release': 525,
#  'visit': 526,
#  'known': 527,
#  'weapons': 528,
#  'interview': 529,
#  'yet': 530,
#  'west': 531,
#  'family': 532,
#  'stock': 533,
#  'india': 534,
#  'mccain': 535,
#  'europe': 536,
#  'detained': 537,
#  'almost': 538,
#  'sea': 539,
#  'wanted': 540,
#  'order': 541,
#  'place': 542,
#  'business': 543,
#  'me': 544,
#  'position': 545,
#  'airport': 546,
#  'body': 547,
#  'face': 548,
#  'morning': 549,
#  'groups': 550,
#  'record': 551,
#  'series': 552,
#  'efforts': 553,
#  'weekend': 554,
#  'showed': 555,
#  'station': 556,
#  'sex': 557,
#  'denied': 558,
#  'believed': 559,
#  'become': 560,
#  'history': 561,
#  'israel': 562,
#  'labor': 563,
#  'though': 564,
#  'opened': 565,
#  'reporters': 566,
#  'democrats': 567,
#  'december': 568,
#  'working': 569,
#  'ban': 570,
#  'vice': 571,
#  'father': 572,
#  'person': 573,
#  '7': 574,
#  'armed': 575,
#  'side': 576,
#  'involved': 577,
#  'russian': 578,
#  'ambassador': 579,
#  'open': 580,
#  'grand': 581,
#  'coast': 582,
#  'control': 583,
#  'roh': 584,
#  'less': 585,
#  'led': 586,
#  'announcement': 587,
#  'comments': 588,
#  '9': 589,
#  'san': 590,
#  'based': 591,
#  'keep': 592,
#  'republic': 593,
#  '8': 594,
#  'incident': 595,
#  'information': 596,
#  'associated': 597,
#  'voters': 598,
#  'real': 599,
#  'northern': 600,
#  'policy': 601,
#  'race': 602,
#  'demand': 603,
#  'australia': 604,
#  'wife': 605,
#  'really': 606,
#  'look': 607,
#  'total': 608,
#  'com': 609,
#  'live': 610,
#  'service': 611,
#  'share': 612,
#  'heart': 613,
#  'inside': 614,
#  'fall': 615,
#  'front': 616,
#  'agreed': 617,
#  'send': 618,
#  'markets': 619,
#  'decided': 620,
#  'david': 621,
#  'blamed': 622,
#  'organization': 623,
#  'prison': 624,
#  'terrorist': 625,
#  'doesn': 626,
#  'games': 627,
#  'cities': 628,
#  'middle': 629,
#  '2003': 630,
#  'old': 631,
#  'germany': 632,
#  '19': 633,
#  'coalition': 634,
#  'researchers': 635,
#  'earth': 636,
#  'these': 637,
#  'pressure': 638,
#  'points': 639,
#  'taking': 640,
#  'never': 641,
#  'daughter': 642,
#  'senior': 643,
#  'trial': 644,
#  'scheduled': 645,
#  'hold': 646,
#  'communist': 647,
#  '25': 648,
#  'room': 649,
#  'los': 650,
#  'game': 651,
#  'evening': 652,
#  'eastern': 653,
#  'important': 654,
#  'consumer': 655,
#  'comes': 656,
#  'plane': 657,
#  'charged': 658,
#  'within': 659,
#  'effect': 660,
#  'speaking': 661,
#  'biggest': 662,
#  'stay': 663,
#  'win': 664,
#  'despite': 665,
#  'claimed': 666,
#  'access': 667,
#  'name': 668,
#  'france': 669,
#  'space': 670,
#  'commission': 671,
#  'satellite': 672,
#  'action': 673,
#  'george': 674,
#  '18': 675,
#  'system': 676,
#  'lost': 677,
#  'lawmakers': 678,
#  'sent': 679,
#  'again': 680,
#  'june': 681,
#  'member': 682,
#  '2005': 683,
#  'heard': 684,
#  'november': 685,
#  'kept': 686,
#  'named': 687,
#  'heavy': 688,
#  'federal': 689,
#  'parliament': 690,
#  'musharraf': 691,
#  'prevent': 692,
#  'bhutto': 693,
#  'goal': 694,
#  'anything': 695,
#  'amid': 696,
#  'lot': 697,
#  'event': 698,
#  'strike': 699,
#  'european': 700,
#  'round': 701,
#  'tournament': 702,
#  'confirmed': 703,
#  'park': 704,
#  'parliamentary': 705,
#  'embassy': 706,
#  'identified': 707,
#  'homes': 708,
#  'committee': 709,
#  'king': 710,
#  'fuel': 711,
#  'worldwide': 712,
#  'smith': 713,
#  'angeles': 714,
#  '2002': 715,
#  'arrived': 716,
#  'senator': 717,
#  'needed': 718,
#  'eight': 719,
#  'ruling': 720,
#  'council': 721,
#  'treatment': 722,
#  'process': 723,
#  'negotiations': 724,
#  'starting': 725,
#  'season': 726,
#  'protest': 727,
#  'looked': 728,
#  'survey': 729,
#  'gen': 730,
#  'qaeda': 731,
#  'fears': 732,
#  'industrial': 733,
#  'tour': 734,
#  'missing': 735,
#  'full': 736,
#  '23': 737,
#  'movie': 738,
#  'clear': 739,
#  'although': 740,
#  'returned': 741,
#  '22': 742,
#  'feel': 743,
#  'senate': 744,
#  'followed': 745,
#  'per': 746,
#  'attempt': 747,
#  'issued': 748,
#  'son': 749,
#  'act': 750,
#  'phone': 751,
#  'afternoon': 752,
#  'host': 753,
#  'congress': 754,
#  'film': 755,
#  'p': 756,
#  'computer': 757,
#  'claims': 758,
#  'gates': 759,
#  'minutes': 760,
#  'summit': 761,
#  'critical': 762,
#  'companies': 763,
#  'address': 764,
#  'search': 765,
#  'board': 766,
#  'popular': 767,
#  'bus': 768,
#  'severe': 769,
#  'warned': 770,
#  'price': 771,
#  'areas': 772,
#  'each': 773,
#  'best': 774,
#  'leading': 775,
#  'brought': 776,
#  'probably': 777,
#  'deaths': 778,
#  'reached': 779,
#  'supporters': 780,
#  'husband': 781,
#  'community': 782,
#  'republican': 783,
#  'county': 784,
#  'cuba': 785,
#  'district': 786,
#  '800': 787,
#  'ground': 788,
#  'massive': 789,
#  'diplomatic': 790,
#  'rates': 791,
#  'michael': 792,
#  'fact': 793,
#  'step': 794,
#  'illegal': 795,
#  'nato': 796,
#  'every': 797,
#  'fight': 798,
#  'debate': 799,
#  'turned': 800,
#  'programs': 801,
#  'independence': 802,
#  'toward': 803,
#  'words': 804,
#  'career': 805,
#  'seeing': 806,
#  '27': 807,
#  'letter': 808,
#  'votes': 809,
#  'jones': 810,
#  'seven': 811,
#  '2004': 812,
#  'often': 813,
#  'asked': 814,
#  'doing': 815,
#  'calls': 816,
#  'xinhua': 817,
#  'association': 818,
#  'light': 819,
#  'fourth': 820,
#  'current': 821,
#  'america': 822,
#  'events': 823,
#  'sources': 824,
#  'rate': 825,
#  'together': 826,
#  'tokyo': 827,
#  'fighting': 828,
#  'western': 829,
#  'difficult': 830,
#  'cars': 831,
#  'intelligence': 832,
#  'test': 833,
#  'august': 834,
#  'worked': 835,
#  'result': 836,
#  'africa': 837,
#  'done': 838,
#  'offered': 839,
#  'condition': 840,
#  'either': 841,
#  'turn': 842,
#  'student': 843,
#  'music': 844,
#  'kenya': 845,
#  'harry': 846,
#  'black': 847,
#  'relations': 848,
#  'whose': 849,
#  'running': 850,
#  'able': 851,
#  'rose': 852,
#  'previously': 853,
#  'published': 854,
#  'chairman': 855,
#  'officers': 856,
#  'low': 857,
#  'refused': 858,
#  'immediately': 859,
#  'parents': 860,
#  'trading': 861,
#  'falling': 862,
#  'credit': 863,
#  'turkish': 864,
#  'faces': 865,
#  'meetings': 866,
#  'closed': 867,
#  'un': 868,
#  'forced': 869,
#  '24': 870,
#  'staff': 871,
#  'tried': 872,
#  'paul': 873,
#  'planning': 874,
#  'parts': 875,
#  'workers': 876,
#  'nearby': 877,
#  'african': 878,
#  'continue': 879,
#  'o': 880,
#  'fans': 881,
#  'thai': 882,
#  'once': 883,
#  'camp': 884,
#  'currently': 885,
#  'cup': 886,
#  'expressed': 887,
#  'situation': 888,
#  '50': 889,
#  'assembly': 890,
#  'living': 891,
#  'candidates': 892,
#  'private': 893,
#  'spending': 894,
#  'poor': 895,
#  'offer': 896,
#  'bid': 897,
#  '21': 898,
#  'virginia': 899,
#  'murder': 900,
#  'sold': 901,
#  'especially': 902,
#  'islamic': 903,
#  'soon': 904,
#  'different': 905,
#  'opening': 906,
#  'problems': 907,
#  'condemned': 908,
#  'adviser': 909,
#  'attorney': 910,
#  'pakistani': 911,
#  'cause': 912,
#  'industry': 913,
#  'primary': 914,
#  'responsibility': 915,
#  'awards': 916,
#  'voted': 917,
#  'victory': 918,
#  'signed': 919,
#  'policies': 920,
#  'taiwan': 921,
#  'thailand': 922,
#  'society': 923,
#  'joint': 924,
#  'downtown': 925,
#  'remaining': 926,
#  'delegates': 927,
#  '80': 928,
#  'average': 929,
#  'trip': 930,
#  'e': 931,
#  'cat': 932,
#  'services': 933,
#  'begin': 934,
#  'tv': 935,
#  'pictures': 936,
#  'street': 937,
#  'net': 938,
#  'included': 939,
#  'syria': 940,
#  'injured': 941,
#  'damage': 942,
#  'richard': 943,
#  'didn': 944,
#  'saw': 945,
#  'resolution': 946,
#  'italian': 947,
#  'young': 948,
#  'governor': 949,
#  'isn': 950,
#  'increase': 951,
#  'available': 952,
#  'interest': 953,
#  'lack': 954,
#  'natural': 955,
#  '2000': 956,
#  'allow': 957,
#  'leave': 958,
#  'occurred': 959,
#  'playing': 960,
#  'minute': 961,
#  'believe': 962,
#  'commander': 963,
#  'strong': 964,
#  'boy': 965,
#  'climate': 966,
#  'officer': 967,
#  'americans': 968,
#  'legal': 969,
#  'battle': 970,
#  'joined': 971,
#  'clashes': 972,
#  'looking': 973,
#  'suggest': 974,
#  'al-maliki': 975,
#  'failed': 976,
#  'activists': 977,
#  'effort': 978,
#  'mark': 979,
#  '500': 980,
#  'discuss': 981,
#  'cell': 982,
#  'worth': 983,
#  'medical': 984,
#  'child': 985,
#  'remarks': 986,
#  'does': 987,
#  'wants': 988,
#  'calling': 989,
#  'index': 990,
#  'exchange': 991,
#  'above': 992,
#  'lone': 993,
#  'hope': 994,
#  'cooperation': 995,
#  'meanwhile': 996,
#  'zimbabwe': 997,
#  'threat': 998,
#  'pacific': 999,
#  'caused': 1000,
#  ...}

# %%
# Define eval_step

@tf.function
def eval_step(src, tgt, encoder, decoder, dec_tok):
    bsz = src.shape[0]
    loss = 0

    enc_out = encoder(src)

    h_dec = enc_out[:, -1]

    dec_src = tf.expand_dims([dec_tok.word_index['<start>']] * bsz, 1)

    for t in range(1, tgt.shape[1]):
        pred, h_dec, _ = decoder(dec_src, h_dec, enc_out)

        loss += loss_function(tgt[:, t], pred)
        dec_src = tf.expand_dims(tgt[:, t], 1)

    batch_loss = (loss / int(tgt.shape[1]))

    return batch_loss


# Training Process

from tqdm import tqdm

EPOCHS = 10

for epoch in range(EPOCHS):
    total_loss = 0

    idx_list = list(range(0, enc_train.shape[0], BATCH_SIZE))
    random.shuffle(idx_list)
    t = tqdm(idx_list)

    for (batch, idx) in enumerate(t):
        batch_loss = train_step(enc_train[idx:idx+BATCH_SIZE],
                                dec_train[idx:idx+BATCH_SIZE],
                                encoder,
                                decoder,
                                optimizer,
                                dec_tokenizer)

        total_loss += batch_loss

        t.set_description_str('Epoch %2d' % (epoch + 1))
        t.set_postfix_str('Loss %.4f' % (total_loss.numpy() / (batch + 1)))

    test_loss = 0

    idx_list = list(range(0, enc_val.shape[0], BATCH_SIZE))
    random.shuffle(idx_list)
    t = tqdm(idx_list)

    for (test_batch, idx) in enumerate(t):
        test_batch_loss = eval_step(enc_val[idx:idx+BATCH_SIZE],
                                    dec_val[idx:idx+BATCH_SIZE],
                                    encoder,
                                    decoder,
                                    dec_tokenizer)

        test_loss += test_batch_loss

        t.set_description_str('Test Epoch %2d' % (epoch + 1))
        t.set_postfix_str('Test Loss %.4f' % (test_loss.numpy() / (test_batch + 1)))
# Out:
# Epoch  1: 100%|██████████| 2275/2275 [11:13<00:00,  3.38it/s, Loss 2.3668]
# Test Epoch  1: 100%|██████████| 569/569 [01:25<00:00,  6.65it/s, Test Loss 3.0205]
# Epoch  2: 100%|██████████| 2275/2275 [11:13<00:00,  3.38it/s, Loss 2.3544]
# Test Epoch  2: 100%|██████████| 569/569 [01:05<00:00,  8.75it/s, Test Loss 2.8650]
# Epoch  3: 100%|██████████| 2275/2275 [11:13<00:00,  3.38it/s, Loss 2.3578]
# Test Epoch  3: 100%|██████████| 569/569 [01:05<00:00,  8.73it/s, Test Loss 2.7455]
# Epoch  4: 100%|██████████| 2275/2275 [11:13<00:00,  3.38it/s, Loss 2.4689]
# Test Epoch  4: 100%|██████████| 569/569 [01:05<00:00,  8.75it/s, Test Loss 2.8686]
# Epoch  5: 100%|██████████| 2275/2275 [11:13<00:00,  3.38it/s, Loss 2.4018]
# Test Epoch  5: 100%|██████████| 569/569 [01:05<00:00,  8.75it/s, Test Loss 2.7934]
# Epoch  6: 100%|██████████| 2275/2275 [11:13<00:00,  3.38it/s, Loss 2.3840]
# Test Epoch  6: 100%|██████████| 569/569 [01:05<00:00,  8.73it/s, Test Loss 2.7630]
# Epoch  7: 100%|██████████| 2275/2275 [11:13<00:00,  3.38it/s, Loss 2.3686]
# Test Epoch  7: 100%|██████████| 569/569 [01:05<00:00,  8.73it/s, Test Loss 2.8147]
# Epoch  8: 100%|██████████| 2275/2275 [11:13<00:00,  3.38it/s, Loss 2.3861]
# Test Epoch  8: 100%|██████████| 569/569 [01:05<00:00,  8.71it/s, Test Loss 2.9525]
# Epoch  9: 100%|██████████| 2275/2275 [11:13<00:00,  3.38it/s, Loss 2.7051]
# Test Epoch  9: 100%|██████████| 569/569 [01:04<00:00,  8.75it/s, Test Loss 3.0678]
# Epoch 10: 100%|██████████| 2275/2275 [11:13<00:00,  3.38it/s, Loss 2.9157]
# Test Epoch 10: 100%|██████████| 569/569 [01:05<00:00,  8.73it/s, Test Loss 3.0212]

# %%
# !sudo apt-get install -y fonts-nanum
# !sudo fc-cache -fv
# !rm ~/.cache/matplotlib -rf
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# fonts-nanum is already the newest version (20180306-3).
# The following packages were automatically installed and are no longer required:
#   accountsservice-ubuntu-schemas bc bluez-obexd cups cups-browsed cups-client
#   cups-common cups-core-drivers cups-daemon cups-filters
#   cups-filters-core-drivers cups-ipp-utils cups-ppdc cups-server-common
#   fonts-droid-fallback fonts-noto-mono fonts-urw-base35 ghostscript
#   gir1.2-dbusmenu-glib-0.4 gnome-bluetooth gnome-power-manager
#   gnome-screensaver gsettings-ubuntu-schemas gvfs-backends indicator-applet
#   indicator-application indicator-appmenu indicator-bluetooth indicator-common
#   indicator-datetime indicator-keyboard indicator-messages indicator-power
#   indicator-printers indicator-session indicator-sound jayatana
#   libaccounts-glib0 libbamf3-2 libcdio-cdda2 libcdio-paranoia2 libcdio18
#   libcupsfilters1 libfcitx-config4 libfcitx-gclient1 libfcitx-utils0
#   libfontembed1 libgnome-panel0 libgs9 libgs9-common libido3-0.1-0 libijs-0.35
#   libindicator3-7 libjbig2dec0 liblightdm-gobject-1-0 liblouis-data liblouis20
#   liblouisutdml-bin liblouisutdml-data liblouisutdml9 libmessaging-menu0
#   libmtp-common libmtp-runtime libmtp9 libnfs13 libpaper-utils libpaper1
#   libpoppler-cpp0v5 libqpdf26 libunity-gtk2-parser0 libunity-gtk3-parser0
#   libunity-settings-daemon1 liburl-dispatcher1 lightdm nautilus-data
#   poppler-utils python3-psutil python3-xdg ssl-cert ubuntu-touch-sounds
#   unity-greeter unity-gtk-module-common unity-gtk2-module unity-gtk3-module
#   unity-settings-daemon unity-settings-daemon-schemas
# Use 'sudo apt autoremove' to remove them.
# 0 upgraded, 0 newly installed, 0 to remove and 0 not upgraded.
# /usr/share/fonts: caching, new cache contents: 0 fonts, 6 dirs
# /usr/share/fonts/X11: caching, new cache contents: 0 fonts, 4 dirs
# /usr/share/fonts/X11/Type1: caching, new cache contents: 8 fonts, 0 dirs
# /usr/share/fonts/X11/encodings: caching, new cache contents: 0 fonts, 1 dirs
# /usr/share/fonts/X11/encodings/large: caching, new cache contents: 0 fonts, 0 dirs
# /usr/share/fonts/X11/misc: caching, new cache contents: 89 fonts, 0 dirs
# /usr/share/fonts/X11/util: caching, new cache contents: 0 fonts, 0 dirs
# /usr/share/fonts/cMap: caching, new cache contents: 0 fonts, 0 dirs
# /usr/share/fonts/cmap: caching, new cache contents: 0 fonts, 5 dirs
# /usr/share/fonts/cmap/adobe-cns1: caching, new cache contents: 0 fonts, 0 dirs
# /usr/share/fonts/cmap/adobe-gb1: caching, new cache contents: 0 fonts, 0 dirs
# /usr/share/fonts/cmap/adobe-japan1: caching, new cache contents: 0 fonts, 0 dirs
# /usr/share/fonts/cmap/adobe-japan2: caching, new cache contents: 0 fonts, 0 dirs
# /usr/share/fonts/cmap/adobe-korea1: caching, new cache contents: 0 fonts, 0 dirs
# /usr/share/fonts/opentype: caching, new cache contents: 0 fonts, 1 dirs
# /usr/share/fonts/opentype/urw-base35: caching, new cache contents: 35 fonts, 0 dirs
# /usr/share/fonts/truetype: caching, new cache contents: 0 fonts, 7 dirs
# /usr/share/fonts/truetype/dejavu: caching, new cache contents: 22 fonts, 0 dirs
# /usr/share/fonts/truetype/droid: caching, new cache contents: 1 fonts, 0 dirs
# /usr/share/fonts/truetype/liberation: caching, new cache contents: 16 fonts, 0 dirs
# /usr/share/fonts/truetype/nanum: caching, new cache contents: 10 fonts, 0 dirs
# /usr/share/fonts/truetype/noto: caching, new cache contents: 1 fonts, 0 dirs
# /usr/share/fonts/truetype/quicksand: caching, new cache contents: 4 fonts, 0 dirs
# /usr/share/fonts/truetype/ubuntu: caching, new cache contents: 14 fonts, 0 dirs
# /usr/share/fonts/type1: caching, new cache contents: 0 fonts, 1 dirs
# /usr/share/fonts/type1/urw-base35: caching, new cache contents: 35 fonts, 0 dirs
# /usr/local/share/fonts: caching, new cache contents: 0 fonts, 0 dirs
# /root/.local/share/fonts: skipping, no such directory
# /root/.fonts: skipping, no such directory
# /usr/share/fonts/X11: skipping, looped directory detected
# /usr/share/fonts/cMap: skipping, looped directory detected
# /usr/share/fonts/cmap: skipping, looped directory detected
# /usr/share/fonts/opentype: skipping, looped directory detected
# /usr/share/fonts/truetype: skipping, looped directory detected
# /usr/share/fonts/type1: skipping, looped directory detected
# /usr/share/fonts/X11/Type1: skipping, looped directory detected
# /usr/share/fonts/X11/encodings: skipping, looped directory detected
# /usr/share/fonts/X11/misc: skipping, looped directory detected
# /usr/share/fonts/X11/util: skipping, looped directory detected
# /usr/share/fonts/cmap/adobe-cns1: skipping, looped directory detected
# /usr/share/fonts/cmap/adobe-gb1: skipping, looped directory detected
# /usr/share/fonts/cmap/adobe-japan1: skipping, looped directory detected
# /usr/share/fonts/cmap/adobe-japan2: skipping, looped directory detected
# /usr/share/fonts/cmap/adobe-korea1: skipping, looped directory detected
# /usr/share/fonts/opentype/urw-base35: skipping, looped directory detected
# /usr/share/fonts/truetype/dejavu: skipping, looped directory detected
# /usr/share/fonts/truetype/droid: skipping, looped directory detected
# /usr/share/fonts/truetype/liberation: skipping, looped directory detected
# /usr/share/fonts/truetype/nanum: skipping, looped directory detected
# /usr/share/fonts/truetype/noto: skipping, looped directory detected
# /usr/share/fonts/truetype/quicksand: skipping, looped directory detected
# /usr/share/fonts/truetype/ubuntu: skipping, looped directory detected
# /usr/share/fonts/type1/urw-base35: skipping, looped directory detected
# /usr/share/fonts/X11/encodings/large: skipping, looped directory detected
# /var/cache/fontconfig: cleaning cache directory
# /root/.cache/fontconfig: not cleaning non-existent cache directory
# /root/.fontconfig: not cleaning non-existent cache directory
# fc-cache: succeeded

# %%
def evaluate(sentence, encoder, decoder):
    attention = np.zeros((dec_train.shape[-1], enc_train.shape[-1]))
    
    sentence = preprocess_sentence(sentence)
#    inputs = enc_tokenizer.texts_to_sequences([sentence.split()])
    inputs = enc_tokenizer.texts_to_sequences([sentence])
    inputs = tf.keras.preprocessing.sequence.pad_sequences(inputs,
                                                           maxlen=enc_train.shape[-1],
                                                           padding='post')

    result = ''

    enc_out = encoder(inputs)

    dec_hidden = enc_out[:, -1]
    dec_input = tf.expand_dims([dec_tokenizer.word_index['<start>']], 0)

    for t in range(dec_train.shape[-1]):
        predictions, dec_hidden, attention_weights = decoder(dec_input,
                                                             dec_hidden,
                                                             enc_out)

        attention_weights = tf.reshape(attention_weights, (-1, ))
        attention[t] = attention_weights.numpy()

        predicted_id = \
        tf.argmax(tf.math.softmax(predictions, axis=-1)[0]).numpy()

        result += dec_tokenizer.index_word[predicted_id] + ' '

        if dec_tokenizer.index_word[predicted_id] == '':
            return result, sentence, attention

        dec_input = tf.expand_dims([predicted_id], 0)

    return result, sentence, attention


def plot_attention(attention, sentence, predicted_sentence):
    fig = plt.figure(figsize=(10, 10))
    ax = fig.add_subplot(1, 1, 1)
    ax.matshow(attention, cmap='viridis')
    
    fontdict = {'fontsize': 14}
    
    ax.set_xticklabels(['<start>'] + sentence, fontdict=fontdict, rotation=90)
    ax.set_yticklabels(['<end>'] + predicted_sentence, fontdict=fontdict)
    
    ax.xaxis.set_major_locator(ticker.MultipleLocator(1))
    ax.yaxis.set_major_locator(ticker.MultipleLocator(1))
    
    plt.show()
    
def translate(sentence, encoder, decoder):
    result, sentence, attention = evaluate(sentence, encoder, decoder)

    print('Input: %s' % (sentence))
    print('Predicted translation: {}'.format(result))
    
#    print(result)
#    attention = attention[:len(result.split()), :len(sentence.split())]
    attention = attention[:len(result.split()), :len(sentence)]
#    plot_attention(attention, sentence.split(), result.split(' '))
    plot_attention(attention, sentence, result.split(' '))

# %%
translate("오바마는 대통령이다.", encoder, decoder)
# Out:
# Input: ['오바마', '는', '대통령', '이', '다', '.']
# Predicted translation: american markets . <end> . <end> . <end> . <end> . <end> . <end> . <end> . <end> . <end> . <end> . <end> . <end> . <end> . <end> . <end> . <end> . <end> . <end> . <end> . <end> . <end> . <end> . <end> . <end> . <end> . <end> . <end> . <end> . <end> . <end> . <end> . <end> . <end> . <end> . <end>
# /tmp/ipykernel_48/1146229430.py:46: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(['<start>'] + sentence, fontdict=fontdict, rotation=90)
# /tmp/ipykernel_48/1146229430.py:47: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_yticklabels(['<end>'] + predicted_sentence, fontdict=fontdict)

# %%
translate("시민들은 도시 속에 산다.", encoder, decoder)
# Out:
# Input: ['시민', '들', '은', '도시', '속', '에', '산다', '.']
# Predicted translation: the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the
# /tmp/ipykernel_48/1146229430.py:46: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(['<start>'] + sentence, fontdict=fontdict, rotation=90)
# /tmp/ipykernel_48/1146229430.py:47: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_yticklabels(['<end>'] + predicted_sentence, fontdict=fontdict)

# %%
from nltk.translate.bleu_score import sentence_bleu

# %%
reference = [[ "The", "way", "home", "is", "this", "way"]]
candidate = ["often" "took" "as" "you"]
score1 = sentence_bleu(reference, candidate, weights=(1, 0, 0, 0)) # 1.0
print(score1)
# Out:
# 0

# %%
from nltk.translate import bleu

reference = ["they" ,"ll", "play", "in", "seattle", "nashville", "and ", "san diego"]
candidate = 'they ll play in seattle nashville and san diego'.split()
bleu([reference], candidate)
# Out:
# 0.5873949094699213

# %%
translate("커피는 필요 없다.", encoder, decoder)
# Out:
# Input: ['커피', '는', '필요', '없', '다', '.']
# Predicted translation: the day . <end> . <end> . <end> . <end> . <end> . <end> . <end> . <end> . <end> . <end> . <end> . <end> . <end> . <end> . <end> . <end> . <end> . <end> . <end> . <end> . <end> . <end> . <end> . <end> . <end> . <end> . <end> . <end> . <end> . <end> . <end> . <end> . <end> . <end> . <end>
# /tmp/ipykernel_48/1146229430.py:46: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(['<start>'] + sentence, fontdict=fontdict, rotation=90)
# /tmp/ipykernel_48/1146229430.py:47: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_yticklabels(['<end>'] + predicted_sentence, fontdict=fontdict)

# %%
from nltk.translate.bleu_score import SmoothingFunction
smoothie = SmoothingFunction().method4
reference = ['the', 'cost', 'of', 'purchasing', 'hardware', 'is ', 'a', 'big', 'obstacle']
candidate = 'the issue of it just being a hardware expense is a serious impediment'.split()
bleu([reference], candidate,  smoothing_function=smoothie)
# Out:
# 0.026480261910431388

# %%
# 1-gram individual BLEU
from nltk.translate.bleu_score import sentence_bleu
reference = [['this', 'is', 'small', 'test']]
candidate = ['this', 'is', 'a', 'test']
score = sentence_bleu(reference, candidate, weights=(1, 0, 0, 0))
print(score)
# Out:
# 0.75
# /opt/conda/lib/python3.9/site-packages/nltk/translate/bleu_score.py:515: UserWarning:
# The hypothesis contains 0 counts of 3-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
# /opt/conda/lib/python3.9/site-packages/nltk/translate/bleu_score.py:515: UserWarning:
# The hypothesis contains 0 counts of 4-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)

# %%
translate(" 그들은 시애틀 내시빌 그리고 샌디에이고에서 공연을 합니다.", encoder, decoder)
# Out:
# Input: ['그', '들', '은', '시애틀', '내시빌', '그리고', '샌디에이고', '에서', '공연', '을', '합니다', '.']
# Predicted translation: the shark , the shark , the shark , the shark , the shark , the shark , the shark , the shark , the shark , the shark , the shark , the shark , the shark , the shark , the shark , the shark , the shark , the shark , the shark , the shark , the shark , the shark , the shark , the shark ,
# /tmp/ipykernel_48/1146229430.py:46: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(['<start>'] + sentence, fontdict=fontdict, rotation=90)
# /tmp/ipykernel_48/1146229430.py:47: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_yticklabels(['<end>'] + predicted_sentence, fontdict=fontdict)

# %% [markdown]
# 회고

# %% [markdown]
# 번역 과제에서 주로 쓰이는 Bleu score랑 이에 대한 여러 smoothing 기법에 대해서 한번 더 구체적으로 알아볼 필요가 있다!

# %% [markdown]
# 번역 결과는 좋지 않다.전체 데이터 중 vocabulary size가 너무 크다. 데이터 중 일부만을 가지고 훈련하였으며, 메모리 사용을 최소화하기 위해 batch size를 1로 하는 등 제대로 된 학습이 어려워 나타난 결과로 보인다.
